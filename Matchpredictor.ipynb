# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("C://Users//Lenovo//Documents//deliveries.csv")

# %%
df[
    (df['batting_team'].isin(["Royal Challengers Bangalore", "Royal Challengers Bengaluru"])) |
    (df['bowling_team'].isin(["Royal Challengers Bangalore", "Royal Challengers Bengaluru"]))
]
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260480   1426310       2       Rajasthan Royals  Royal Challengers Bengaluru
# 260481   1426310       2       Rajasthan Royals  Royal Challengers Bengaluru
# 260482   1426310       2       Rajasthan Royals  Royal Challengers Bengaluru
# 260483   1426310       2       Rajasthan Royals  Royal Challengers Bengaluru
# 260484   1426310       2       Rajasthan Royals  Royal Challengers Bengaluru
#
# ...

# %%
df_m=pd.read_csv("C://Users//Lenovo//Documents//matches.csv")

# %%
df_m
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df_m[
    (df_m['team1'].isin(["Royal Challengers Bangalore", "Royal Challengers Bengaluru"])) |
    (df_m['team2'].isin(["Royal Challengers Bangalore", "Royal Challengers Bengaluru"]))
]
# Out:
#            id   season        city        date  match_type player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18      League     BB McCullum
# 3      335985  2007/08      Mumbai  2008-04-20      League      MV Boucher
# 10     335992  2007/08   Bangalore  2008-04-26      League       SR Watson
# 14     335996  2007/08   Bangalore  2008-04-28      League        MS Dhoni
# 16     335998  2007/08       Delhi  2008-04-30      League      GD McGrath
# ...       ...      ...         ...         ...         ...             ...
# 1075  1426290     2024   Bengaluru  2024-05-04      League  Mohammed Siraj
# 1081  1426296     2024  Dharamsala  2024-05-09      League         V Kohli
# 1085  1426300     2024   Bengaluru  2024-05-12      League         C Green
# 1089  1426306     2024   Bengaluru  2024-05-18      League    F du Plessis
# 1092  1426310     2024   Ahmedabad  2024-05-22  Eliminator        R Ashwin
#
#                                                   venue  \
# ...

# %%
df_final=pd.merge(df,df_m,how="inner",left_on="match_id",right_on="id")

# %%
df_final
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
df_final['current_score'] = df_final.groupby(['match_id','inning'])['total_runs'].cumsum()

# %%
df_final['Current_wickets']=df_final.groupby(['match_id','inning'])['is_wicket'].cumsum()

# %%
df_final_chase=df_final[df_final['inning']==2]

# %%
df_model1=df_final_chase[["batting_team","bowling_team","over","ball","Current_wickets","current_score","target_runs","target_overs","venue","winner"]]

# %%
df_model1
# Out:
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 260915        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 260916        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 260917        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 260918        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 260919        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#         Current_wickets  current_score  target_runs  target_overs  \
# ...

# %%
df_model1['winner']=np.where(df_model1['winner']==df_model1['batting_team'],1,0)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20884\85212275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model1['winner']=np.where(df_model1['winner']==df_model1['batting_team'],1,0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
X=df_model1.drop(columns=['winner'])
y=df_model1['winner']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,stratify=y)

# %%
from sklearn.compose import ColumnTransformer

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler,OrdinalEncoder,LabelEncoder

# %%
trf1=ColumnTransformer([('scaling_numerical',StandardScaler(),[2,3,4,5,6,7])],remainder='passthrough')

# %%
trf2 = ColumnTransformer(
    transformers=[('ohe_trans', OneHotEncoder(sparse_output=False),[0,1,8])],
    remainder='passthrough'
)

# %%
from sklearn.feature_selection import SelectKBest,chi2

# %%
trf3=SelectKBest(score_func=chi2,k=20)

# %%
trf4=LogisticRegression(class_weight='balanced')

# %%
from sklearn.pipeline import Pipeline, make_pipeline

# %%
pipe=make_pipeline(trf2,trf1,trf4)

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('columntransformer-1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe_trans',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   [0, 1, 8])])),
#                 ('columntransformer-2',
#                  ColumnTransformer(remainder='passthrough',
# ...

# %%
pipe.named_steps
# Out:
# {'columntransformer-1': ColumnTransformer(remainder='passthrough',
#                    transformers=[('ohe_trans',
#                                   OneHotEncoder(sparse_output=False),
#                                   [0, 1, 8])]),
#  'columntransformer-2': ColumnTransformer(remainder='passthrough',
#                    transformers=[('scaling_numerical', StandardScaler(),
#                                   [2, 3, 4, 5, 6, 7])]),
#  'logisticregression': LogisticRegression(class_weight='balanced')}

# %%
y_pred=pipe.predict(X_test)

# %%
from sklearn.metrics import  accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8003870317843226

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(pipe,X_train,y_train,cv=5,scoring='accuracy').mean()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.metrics import confusion_matrix,precision_score,f1_score,recall_score

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[14436,  3683],
#        [ 3847, 15757]], dtype=int64)

# %%
recall_score(y_test,y_pred)
# Out:
# 0.8037645378494185

# %%
precision_score(y_test,y_pred)
# Out:
# 0.8105452674897119

# %%
f1_score(y_test,y_pred)
# Out:
# 0.8071406618174367

# %%
import pickle

# %%
with open('pipe_model.pkl', 'wb') as f:
    pickle.dump(pipe, f)

# %%
test_data = [['Royal Challengers Bangalore', 'Mumbai Indians', 5, 10, 3, 150, 200, 15, 'Wankhede Stadium']]

# %%
pipe.predict_proba(test_data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# array([[0.20316128, 0.79683872]])

# %%
df_final['extras_type'].unique()
# Out:
# array(['legbyes', nan, 'wides', 'byes', 'noballs', 'penalty'],
#       dtype=object)
